# %% [markdown]
# <a href="https://colab.research.google.com/github/luulytinh/phantichdulieu1/blob/main/lap_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
patientheartrate = pd.read_csv('https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/patient_heart_rate.csv')
patientheartrate.head(5)
# Out:
#      1    Mickéy Mousé    56       70kgs  72  69  71   -  -.1 -.2
# 0  2.0     Donald Duck  34.0   154.89lbs   -   -   -  85   84  76
# 1  3.0      Mini Mouse  16.0         NaN   -   -   -  65   69  72
# 2  4.0  Scrooge McDuck   NaN       78kgs  78  79  72   -    -   -
# 3  5.0    Pink Panther  54.0  198.658lbs   -   -   -  69  NaN  75
# 4  6.0     Huey McDuck  52.0      189lbs   -   -   -  68   75  72

# %%
column_names=["ID", "Name", "Age", "Weight", "m0006", "m0612","m1218", "f006", "f0612", "f1218"]
patientheartrate = pd.read_csv('https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/patient_heart_rate.csv', 
                               names = column_names)
patientheartrate.head(5)
# Out:
#     ID            Name   Age      Weight m0006 m0612 m1218 f006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71    -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -   85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -   65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72    -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -   69   NaN    75

# %%
patientheartrate = patientheartrate.drop('Name',axis=1)
patientheartrate
# Out:
#       ID   Age      Weight m0006 m0612 m1218 f006 f0612 f1218
# 0    1.0  56.0       70kgs    72    69    71    -     -     -
# 1    2.0  34.0   154.89lbs     -     -     -   85    84    76
# 2    3.0  16.0         NaN     -     -     -   65    69    72
# 3    4.0   NaN       78kgs    78    79    72    -     -     -
# 4    5.0  54.0  198.658lbs     -     -     -   69   NaN    75
# 5    6.0  52.0      189lbs     -     -     -   68    75    72
# 6    7.0  19.0       56kgs     -     -     -   71    78    75
# 7    8.0  32.0       78kgs    78    76    75    -     -     -
# 8    NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 9    NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 10   9.0  52.0      189lbs     -     -     -   68    75    72
# 11  10.0  12.0       45kgs     -     -     -   92    95    87
# 12  11.0   NaN       60kgs    78    75    72    -     -     -
# 13  12.0  34.0         NaN    65    67    55    -     -     -
# 14  13.0   NaN         NaN     -     -     -   68    72    70
# 15  14.0   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 16  15.0  52.0      180lbs     -     -     -   68    75    72

# %%
weight=patientheartrate['Weight']
for i in range(len(weight)):
  x = str(weight[i])
  if "lbs" in x[-3:]:
    #remove the lbs from the value
    x = x[:-3:]
    float_x = float(x)
    y = int(float_x/2.205)
    y = str(y)+"kgs"
    weight[i] = y

patientheartrate.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218
# 0  1.0  56.0  70kgs    72    69    71    -     -     -
# 1  2.0  34.0  70kgs     -     -     -   85    84    76
# 2  3.0  16.0    NaN     -     -     -   65    69    72
# 3  4.0   NaN  78kgs    78    79    72    -     -     -
# 4  5.0  54.0  90kgs     -     -     -   69   NaN    75

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')

patientheartrate.dropna(how="all", inplace = True)

# %% [markdown]
# import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# sns.heatmap(patientheartrate.isna(),
#             yticklabels=False,
#             cbar=True,
#             cmap='viridis')
#
# patientheartrate.dropna(how="all", inplace = True)

# %%
patientheartrate = patientheartrate.drop_duplicates(subset=['Firstname','Lastname', 'Age', 'Weight'])
patientheartrate

# %%
patientheartrate.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True,inplace=True)
patientheartrate.head(5)

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')

# %%
index_ageweightnull = patientheartrate[patientheartrate['Age'].isna() & patientheartrate['Weight'].isna()].index
index_ageweightnull
# Out:
# Int64Index([14, 15], dtype='int64')

# %%
patientheartrate.drop(index_ageweightnull, inplace=True)

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')

# %%
patientheartrate['Age'].fillna(patientheartrate['Age'].mean(), inplace =False)
# Out:
# 0     56.000000
# 1     34.000000
# 2     16.000000
# 3     37.545455
# 4     54.000000
# 5     52.000000
# 6     19.000000
# 7     32.000000
# 10    52.000000
# 11    12.000000
# 12    37.545455
# 13    34.000000
# 16    52.000000
# Name: Age, dtype: float64

# %%
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218
# 0    1.0  56.0  70kgs    72    69    71    -     -     -
# 1    2.0  34.0  70kgs     -     -     -   85    84    76
# 2    3.0  16.0    NaN     -     -     -   65    69    72
# 3    4.0   NaN  78kgs    78    79    72    -     -     -
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75
# 5    6.0  52.0  85kgs     -     -     -   68    75    72
# 6    7.0  19.0  56kgs     -     -     -   71    78    75
# 7    8.0  32.0  78kgs    78    76    75    -     -     -
# 10   9.0  52.0  85kgs     -     -     -   68    75    72
# 11  10.0  12.0  45kgs     -     -     -   92    95    87
# 12  11.0   NaN  60kgs    78    75    72    -     -     -
# 13  12.0  34.0    NaN    65    67    55    -     -     -
# 16  15.0  52.0  81kgs     -     -     -   68    75    72

# %%
df = pd.melt(patientheartrate, id_vars=['ID', 'Age', 'Weight', 'Firstname', 'Lastname'], value_name="PulseRate",var_name="sex_and_time").sort_values(['ID', 'Age', 'Weight', 'Firstname', 'Lastname']) 
df

# %%
len(df['PulseRate'])

# %%
df.head(10)
